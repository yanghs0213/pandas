# %%
import pandas as pd
import matplotlib.pyplot as plt
# 차트에 한글 깨지지 않도록 차트 폰트변경
plt.rcParams['font.family'] = 'Malgun Gothic'
# 차트에 "-"문자 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

data = {
    "id": range(1, 31),

    "opinion": [
        "Python basics made data analysis easier",
        "Learning Python data processing was interesting",
        "Pandas practice was useful for data analysis",
        "DataFrame made data cleaning easier",
        "SQL practice helped me understand databases",
        "SQL queries were useful for working with data",
        "Data preprocessing is important in big data analysis",
        "Handling missing values was difficult but useful",
        "Data visualization made analysis results easier to understand",
        "Bar charts and histograms were fun to practice",
        "Scatter plots helped me understand relationships between data",
        "Correlation was easier to understand with charts",
        "Machine learning concepts were interesting",
        "Training machine learning models was fun",
        "I learned the difference between AI and machine learning",
        "Deep learning made me more interested in artificial intelligence",
        "PyTorch practice was useful for learning deep learning",
        "The data analysis project was a valuable experience",
        "The team project helped me practice real data analysis",
        "Using real data made the lessons easier to understand",
        "Data cleaning was more important than I expected",
        "I want to learn more about data visualization",
        "Using Python and SQL together was helpful",
        "The big data project improved my problem solving skills",
        "Python was difficult at first but became easier with practice",
        "I want to learn how to interpret machine learning results",
        "I am interested in using artificial intelligence in real work",
        "I want more experience with data analysis projects",
        "I became interested in careers in big data and AI",
        "The hands-on lessons helped me understand data analysis"
    ]
}

df = pd.DataFrame(data)

df.head()
# Out:
#    id                                          opinion
# 0   1          Python basics made data analysis easier
# 1   2  Learning Python data processing was interesting
# 2   3     Pandas practice was useful for data analysis
# 3   4              DataFrame made data cleaning easier
# 4   5      SQL practice helped me understand databases

# %%
text = " ".join(df["opinion"])
text
# Out:
# 'Python basics made data analysis easier Learning Python data processing was interesting Pandas practice was useful for data analysis DataFrame made data cleaning easier SQL practice helped me understand databases SQL queries were useful for working with data Data preprocessing is important in big data analysis Handling missing values was difficult but useful Data visualization made analysis results easier to understand Bar charts and histograms were fun to practice Scatter plots helped me understand relationships between data Correlation was easier to understand with charts Machine learning concepts were interesting Training machine learning models was fun I learned the difference between AI and machine learning Deep learning made me more interested in artificial intelligence PyTorch practice was useful for learning deep learning The data analysis project was a valuable experience The team project helped me practice real data analysis Using real data made the lessons easier to understand Data cleaning was more important than I expected I want to learn more about data visualization Using Python and SQL together was helpful The big data project improved my problem solving skills Python was difficult at first but became easier with practice I want to learn how to interpret machine learning results I am interested in using artificial intelligence in real work I want more experience with data analysis projects I became interested in careers in big data and AI The hands-on lessons helped me understand data analysis'

# %%
from collections import Counter

# %%
word = text.lower().split()
word[:10]
# Out:
# ['python',
#  'basics',
#  'made',
#  'data',
#  'analysis',
#  'easier',
#  'learning',
#  'python',
#  'data',
#  'processing']

# %%
word_count = Counter(word)
word_count
# Out:
# Counter({'data': 18,
#          'was': 10,
#          'analysis': 8,
#          'learning': 8,
#          'to': 7,
#          'i': 7,
#          'easier': 6,
#          'practice': 6,
#          'understand': 6,
#          'in': 6,
#          'the': 6,
#          'made': 5,
#          'me': 5,
#          'python': 4,
#          'useful': 4,
#          'helped': 4,
#          'with': 4,
#          'and': 4,
#          'machine': 4,
#          'more': 4,
#          'for': 3,
#          'sql': 3,
#          'were': 3,
#          'big': 3,
#          'interested': 3,
#          'project': 3,
#          'real': 3,
#          'using': 3,
#          'want': 3,
#          'interesting': 2,
#          'cleaning': 2,
#          'important': 2,
#          'difficult': 2,
#          'but': 2,
#          'visualization': 2,
#          'results': 2,
#          'charts': 2,
#          'fun': 2,
#          'between': 2,
#          'ai': 2,
#          'deep': 2,
#          'artificial': 2,
#          'intelligence': 2,
#          'experience': 2,
#          'lessons': 2,
#          'learn': 2,
#          'became': 2,
#          'basics': 1,
#          'processing': 1,
#          'pandas': 1,
#          'dataframe': 1,
#          'databases': 1,
#          'queries': 1,
#          'working': 1,
#          'preprocessing': 1,
#          'is': 1,
#          'handling': 1,
#          'missing': 1,
#          'values': 1,
#          'bar': 1,
#          'histograms': 1,
#          'scatter': 1,
#          'plots': 1,
#          'relationships': 1,
#          'correlation': 1,
#          'concepts': 1,
#          'training': 1,
#          'models': 1,
#          'learned': 1,
#          'difference': 1,
#          'pytorch': 1,
#          'a': 1,
#          'valuable': 1,
#          'team': 1,
#          'than': 1,
#          'expected': 1,
#          'about': 1,
#          'together': 1,
#          'helpful': 1,
#          'improved': 1,
#          'my': 1,
#          'problem': 1,
#          'solving': 1,
#          'skills': 1,
#          'at': 1,
#          'first': 1,
#          'how': 1,
#          'interpret': 1,
#          'am': 1,
#          'work': 1,
#          'projects': 1,
#          'careers': 1,
#          'hands-on': 1})

# %%
# %pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.9.6-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in .\.venv\Lib\site-packages (from wordcloud) (2.4.6)
# Requirement already satisfied: pillow in .\.venv\Lib\site-packages (from wordcloud) (12.3.0)
# Requirement already satisfied: matplotlib in .\.venv\Lib\site-packages (from wordcloud) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (26.3)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Using cached wordcloud-1.9.6-cp311-cp311-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# 시각화
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(
    width=800,
    height=500,
    background_color="white",
    stopwords=set()       # 기본 불용어 사용 안 함
).generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
stopwords = {
    "the", "and", "is", "to", "was",
    "a", "of", "in", "with", "me",
    "my", "more", "than", "I"
}

wordcloud = WordCloud(
    width=800,
    height=500,
    background_color="white",
    stopwords=stopwords # 불용어 설정
).generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
