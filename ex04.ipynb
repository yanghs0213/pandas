# %%
import pandas as pd

# %%
t = pd.Series(
    [-2.4, 0.4, 5.7, 12.5, 18.2, 23.0,
     25.8, 26.1, 21.2, 14.8, 7.2, 0.1],
)

t.index = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                    "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# %%
t
# Out:
# Jan    -2.4
# Feb     0.4
# Mar     5.7
# Apr    12.5
# May    18.2
# Jun    23.0
# Jul    25.8
# Aug    26.1
# Sep    21.2
# Oct    14.8
# Nov     7.2
# Dec     0.1
# dtype: float64

# %%
t.iloc[0] = -3.4
t
# Out:
# Jan    -3.4
# Feb     0.4
# Mar     5.7
# Apr    12.5
# May    18.2
# Jun    23.0
# Jul    25.8
# Aug    26.1
# Sep    21.2
# Oct    14.8
# Nov     7.2
# Dec     0.1
# dtype: float64

# %%
t.iloc[6:8] = [30.0, 35.0]
t
# Out:
# Jan    -3.4
# Feb     0.4
# Mar     5.7
# Apr    12.5
# May    18.2
# Jun    23.0
# Jul    30.0
# Aug    35.0
# Sep    21.2
# Oct    14.8
# Nov     7.2
# Dec     0.1
# dtype: float64

# %%
t.loc["AVG"] = t.mean()
t
# Out:
# Jan    -3.400
# Feb     0.400
# Mar     5.700
# Apr    12.500
# May    18.200
# Jun    23.000
# Jul    30.000
# Aug    35.000
# Sep    21.200
# Oct    14.800
# Nov     7.200
# Dec     0.100
# AVG    13.725
# dtype: float64

# %%
t.drop("AVG")
t
# Out:
# Jan    -3.400
# Feb     0.400
# Mar     5.700
# Apr    12.500
# May    18.200
# Jun    23.000
# Jul    30.000
# Aug    35.000
# Sep    21.200
# Oct    14.800
# Nov     7.200
# Dec     0.100
# AVG    13.725
# dtype: float64

# %%
t2 = t.drop("AVG")
t2
# Out:
# Jan    -3.4
# Feb     0.4
# Mar     5.7
# Apr    12.5
# May    18.2
# Jun    23.0
# Jul    30.0
# Aug    35.0
# Sep    21.2
# Oct    14.8
# Nov     7.2
# Dec     0.1
# dtype: float64
