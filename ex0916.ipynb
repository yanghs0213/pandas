# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img1 = mpimg.imread("cat.jpg")
img2 = mpimg.imread("dog.jpg")
img3 = mpimg.imread("flower.jpg")
img4 = mpimg.imread("car.jpg")
print(img1, img2, img3, img4)
# Out:
# [[[254 254 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [249 245 246]
#   [249 247 250]
#   [255 254 255]]
#
#  [[254 254 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 254 255]
#   [254 252 255]
#   [255 254 255]]
#
#  [[254 254 255]
#   [255 255 255]
#   [254 254 255]
#   ...
#   [255 254 253]
#   [255 253 255]
#   [253 251 255]]
#
#  ...
#
#  [[255 253 255]
#   [255 253 253]
#   [255 251 247]
#   ...
#   [255 253 249]
#   [253 249 246]
#   [248 247 245]]
#
#  [[255 250 255]
#   [255 254 255]
#   [255 253 250]
#   ...
#   [255 254 251]
#   [249 248 246]
#   [250 249 247]]
#
#  [[254 251 255]
#   [255 254 255]
#   [252 251 249]
#   ...
#   [255 254 255]
#   [252 250 251]
#   [254 252 253]]] [[[253 242 248]
#   [255 250 255]
#   [255 249 255]
#   ...
#   [255 255 255]
#   [249 249 249]
#   [255 255 255]]
#
#  [[255 244 250]
#   [255 252 255]
#   [253 247 251]
#   ...
#   [247 247 247]
#   [251 251 251]
#   [250 250 250]]
#
#  [[246 237 242]
#   [255 252 255]
# ...

# %%
fig = plt.figure()
print(fig)
# Out:
# Figure(640x480)

# %%
# figure를 2x2로 4개의 공간을 지정
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.imshow(img1) # 이미지를 가져다 놓을 수도, ...차트를 그릴수도...
axes2.imshow(img2)
axes3.imshow(img3)
axes4.imshow(img4)

# %%
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# ============================================================
# 1. 이미지 불러오기
# ============================================================

# 이미지 파일을 읽어온다.
# imread() → 이미지 파일을 읽어서 배열 형태로 반환한다.

img1 = mpimg.imread("cat.jpg")
img2 = mpimg.imread("dog.jpg")
img3 = mpimg.imread("flower.jpg")
img4 = mpimg.imread("car.jpg")


# ============================================================
# 2. 전체 Figure 생성
# ============================================================

# 여러 이미지를 담을 전체 도화지(Figure)를 생성한다.
#
# figsize=(10, 8)
# → 전체 Figure의 크기
# → 가로 10인치, 세로 8인치

fig = plt.figure(figsize=(10, 8))


# ============================================================
# 3. 첫 번째 이미지 공간 생성
# ============================================================

# Figure를 2행 2열로 나누고
# 그중 첫 번째 위치에 그래프 공간(Axes)을 생성한다.
axes1 = fig.add_subplot(2, 2, 1)

# 첫 번째 이미지 표시
axes1.imshow(img1)

# 이미지 제목
axes1.set_title("Cat")

# x축, y축 눈금 제거
axes1.axis("off")


# ============================================================
# 4. 두 번째 이미지 공간 생성
# ============================================================

# 2행 2열 중 두 번째 위치
axes2 = fig.add_subplot(2, 2, 2)

# 두 번째 이미지 표시
axes2.imshow(img2)

# 이미지 제목
axes2.set_title("Dog")

# 축 제거
axes2.axis("off")


# ============================================================
# 5. 세 번째 이미지 공간 생성
# ============================================================

# 2행 2열 중 세 번째 위치
axes3 = fig.add_subplot(2, 2, 3)

# 세 번째 이미지 표시
axes3.imshow(img3)

# 이미지 제목
axes3.set_title("Flower")

# 축 제거
axes3.axis("off")


# ============================================================
# 6. 네 번째 이미지 공간 생성
# ============================================================

# 2행 2열 중 네 번째 위치
axes4 = fig.add_subplot(2, 2, 4)

# 네 번째 이미지 표시
axes4.imshow(img4)

# 이미지 제목
axes4.set_title("Car")

# 축 제거
axes4.axis("off")


# ============================================================
# 7. 이미지 간격 조정
# ============================================================

# 이미지와 제목 사이의 간격을 자동으로 조정한다.
fig.tight_layout()


# ============================================================
# 8. Figure 출력
# ============================================================

# 완성된 Figure를 화면에 출력한다.
plt.show()

# %%
x1 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

x2 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]

x3 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
# 데이터의 기술 통계량이 동일한 데이터
import numpy as np

# 4개의 데이터셋을 하나로 묶기
datasets = [
    (x1, y1),
    (x2, y2),
    (x3, y3),
    (x4, y4)
]


# 데이터셋별 통계량 계산
for i, (x, y) in enumerate(datasets, start=1):

    # 리스트를 NumPy 배열로 변환
    x = np.array(x)
    y = np.array(y)

    # 평균
    x_mean = np.mean(x)
    y_mean = np.mean(y)

    # 분산
    # ddof=1 → 표본분산
    x_var = np.var(x, ddof=1)
    y_var = np.var(y, ddof=1)

    # 상관계수
    correlation = np.corrcoef(x, y)[0, 1]

    # 회귀선
    # y = a*x + b
    # a = 기울기, b = 절편
    a, b = np.polyfit(x, y, 1)

    print(f"\n[Dataset {i}]")

    print(f"x 평균     : {x_mean:.2f}")
    print(f"y 평균     : {y_mean:.2f}")

    print(f"x 분산     : {x_var:.2f}")
    print(f"y 분산     : {y_var:.2f}")

    print(f"상관계수   : {correlation:.2f}")

    print(f"회귀선 기울기 : {a:.2f}")
    print(f"회귀선 절편   : {b:.2f}")

    print(f"회귀식     : y = {a:.2f}x + {b:.2f}")
# Out:
# [Dataset 1]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.13
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00
#
# [Dataset 2]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.13
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00
#
# [Dataset 3]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.12
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00
#
# [Dataset 4]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.12
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00

# %%
fig = plt.figure(figsize=(10, 8))
axes1 = fig.add_subplot(2, 2, 1)
axes1.scatter(x1, y1) # scatter(산점도) 차트를 그린다.
axes1.set_title("Dataset 1")

axes2 = fig.add_subplot(2, 2, 2)
axes2.scatter(x2, y2) # scatter(산점도) 차트를 그린다.
axes2.set_title("Dataset 2")

axes3 = fig.add_subplot(2, 2, 3)
axes3.scatter(x3, y3) # scatter(산점도) 차트를 그린다.
axes3.set_title("Dataset 3")

axes4 = fig.add_subplot(2, 2, 4)
axes4.scatter(x4, y4) # scatter(산점도) 차트를 그린다.
axes4.set_title("Dataset 4")

fig.tight_layout()
plt.show()
